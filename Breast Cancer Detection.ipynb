# %% [markdown]
# #  Introduction

# %% [markdown]
# Breast cancer stands as a prominent and pressing health issue, marked by the unbridled proliferation of cells within the breast tissue. Globally, it ranks as the most frequently diagnosed cancer among women, impacting millions annually. As per the World Health Organization (WHO), breast cancer tops the list of diagnosed cancers in women across the world.
#
# Within the realm of breast cancer, a critical hurdle lies in the accurate diagnosis and effective treatment of the disease. This project endeavors to address this challenge by crafting a robust machine learning model. The primary objective is to develop a system that proficiently classifies tumors, distinguishing between malignant (cancerous) and benign (non-cancerous) entities. Through this innovative approach, the aim is to contribute to advancements in diagnostic precision and treatment efficacy for breast cancer.

# %% [markdown]
# ### Objective

# %% [markdown]
# This study aimed to predict breast cancer using different machine-learning approaches applying demographic, laboratory, and mammographic data.

# %% [markdown]
# ###  Details About Datasets

# %% [markdown]
# This dataset consists of various medical parameters related to breast cancer .
# Tumor Size , Tumor Stage, Histological Type, Histological Grade, Hormone Receptor Status, HER2 Status, Lymph Node Involvement , Metastasis these are few contents that breast cancer dataset consist of.
# Utilizing these features, we aim to analyze and construct a classification model designed to detect the presence of cancer.

# %% [markdown]
# ### Loading Datasets

# %% [markdown]
# Loading a dataset into a Jupyter Notebook is a crucial step in the data analysis and machine learning workflow.
# Following can be considered as the most important steps for loading datasets :-
# * Data Exploration
# * Data Cleaning
# * Data Visualization
# * Model Building ......etc

# %%
#Importing the required packages
import pandas as pd    
#pandas is a Python package providing fast, flexible, and expressive data structures
#designed to make working with “relational” or “labeled” data both easy and intuitive.
import numpy as np
#NumPy is a Python library used for working with arrays. 
#It also has functions for working in domain of linear algebra, fourier transform, and matrices
import matplotlib.pyplot as plt
#Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
import seaborn as sbn
#Seaborn is a Python data visualization library based on matplotlib. 
#It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
bcancer = pd.read_csv(r"C:\Users\ASUS\Downloads\breast-cancer.csv")    #here we are able o read the csv file

# %%
bcancer.head()     #here starting five rows are displayed
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bcancer.tail()     #here ending  five rows are displayed
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
bcancer.shape
# Out:
# (569, 32)

# %%
bcancer.ndim
# Out:
# 2

# %%
bcancer.size
# Out:
# 18208

# %% [markdown]
# ### Cleaning Datasets

# %% [markdown]
# Before performing any analysis or building machine learning models, it's essential to clean and preprocess the data.
# Loading the dataset enables you to identify missing values, outliers, and other data quality issues that may need to be addressed.

# %%
bcancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#lets check the datatypes and the null values also the nan values 
bcancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#as we got to know the datatypes and the null values details now we will see that which coloumn need to be dropped ......
bcancer = bcancer.drop(['id'],axis=1)

# %%
#converting the categorial column to integer column .... we need to use replace function
bcancer['diagnosis'].replace({'B':0,'M':1},inplace = True)   # we need to  use inplace to make the changes occuring permanent

# %%
bcancer.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
bcancer.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
#no null values

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize=(4,3))
bcancer['diagnosis'].value_counts().plot(kind='bar',color='blue')


plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Count of Diagnostics Results')
plt.show()

# %%
bcancer.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#Visulaizing Numerical columns

for col in bcancer.select_dtypes(include='float').columns:
    plt.figure(figsize=(4,3))
    sbn.distplot(bcancer[col],bins=10,color='blue')
    plt.title(f'Distribution Plot for {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Model Building

# %%
x = bcancer.drop(['diagnosis'],axis=1)
y = bcancer['diagnosis']

# %%
from sklearn.preprocessing import power_transform
x= power_transform(x, method='yeo-johnson', standardize=True, copy=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.datasets import make_classification
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
acc = []
accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy:.2f}')
print('\nConfusion Matrix:')
print(cm)
print('\nClassification Report:')
print(classification_rep)
# Out:
# Accuracy: 0.97
#
# Confusion Matrix:
# [[73  1]
#  [ 2 38]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        74
#            1       0.97      0.95      0.96        40
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test)



accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
classification_rep = classification_report(y_test, y_pred)



print(f'Accuracy: {accuracy:.2f}')
print('\nConfusion Matrix:')
print(cm)
print('\nClassification Report:')
print(classification_rep)
# Out:
# Accuracy: 0.91
#
# Confusion Matrix:
# [[69  5]
#  [ 5 35]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        74
#            1       0.88      0.88      0.88        40
#
#     accuracy                           0.91       114
#    macro avg       0.90      0.90      0.90       114
# weighted avg       0.91      0.91      0.91       114

# %% [markdown]
# ### K-Nearest Neighbors(KNN) Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)


knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)



accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
classification_rep = classification_report(y_test, y_pred)


print(f'Accuracy: {accuracy:.2f}')
print('\nConfusion Matrix:')
print(cm)
print('\nClassification Report:')
print(classification_rep)
# Out:
# Accuracy: 0.96
#
# Confusion Matrix:
# [[71  3]
#  [ 2 38]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        74
#            1       0.93      0.95      0.94        40
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# ### Model Performance

# %% [markdown]
# From all the models, Logistic regression outperfomed other models.
#
# Logistic Regression: 0.97
# Decision Tree Classifier: 0.89
# KNeighbors Classifier: 0.96
